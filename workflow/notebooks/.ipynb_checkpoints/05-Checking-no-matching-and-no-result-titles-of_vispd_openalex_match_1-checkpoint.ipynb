# %% [markdown]
# ## Aim
#
# In this notebook, I aim to see:
#
# - How many papers in `data/interim/title_query_empty_doi_query_404.txt` can be identified if I modify the queried title slightly
# - How many papers that are successfully identified (those in `data/interim/vispd_openalex_match_1.csv`) do not have the same title and are not the same paper.
#
# ## Conclusion
#
# - 11 papers do have results based on title and DOI research. Among those, 4 are able to be identified by title search if I modify their the title query string a little bit.
#
# - For papers that are successfully matched via title search, 56 papers' OpenAlex titles AND OpenAlex DOIs are not exactly the same as information on VISPUBDATA. I manually checked the differences and found that 56 papers have different title AND DOI. Among these, 17 are indeed different. Among these 17, only two, namely, HyperLIC and Escape Maps are not searchable. The remaining 15 can be found by a different index in title query results, simply through DOI search, or slightly change the queried title (removing the string of "#" in the title)
#
# - The conclusion is that only (11-4) + 2 = 9 papers are not able to be identified on OpenAlex.

# %%
import requests
import pandas as pd
import csv
import re
pd.options.display.max_colwidth = 200
pd.set_option('display.max_rows', 500)
import numpy as np

# %%
def read_txt(INPUT):
    """read txt files and return a list
    """
    raw = open(INPUT, "r")
    reader = csv.reader(raw)
    allRows = [row for row in reader]
    data = [i[0] for i in allRows]
    return data

# %%
no_matching = read_txt("../../data/interim/checking/title_query_404_1.txt")

# %%
no_result = read_txt("../../data/interim/checking/title_query_empty_doi_query_404_1.txt")

# %%
# create dicts to convert doi and title, and vice versa
vispd_plus = pd.read_csv("../../data/processed/vispubdata_plus.csv")
dois = vispd_plus.loc[:, "DOI"].tolist()
titles = vispd_plus.loc[:, "Title"].tolist()
doi_title_dict = dict(zip(dois, titles))
title_doi_dict = dict(zip(titles, dois))

# %%
# checking no matching.
no_matching_titles = [doi_title_dict[doi] for doi in no_matching]

# %%
no_matching_titles_transformed = [re.sub(r'\:|\?|\&|\,', '', title) for title in no_matching_titles]

# %%
# empty, which means that every paper can be mathced. 
no_matching_titles
# Out:
# []

# %%
no_matching_titles_transformed
# Out:
# []

# %%
## checking no result titles
## By `no_result`, I mean that for these papers, title queries were successful
## However, the query shows empty results. For example:
## https://api.openalex.org/works?filter=title.search:Generation of Transfer Functions with Stochastic Search Technique
no_result_titles = [doi_title_dict[doi] for doi in no_result]
no_result_titles
no_result_titles_transformed = [re.sub(r'\:|\?|\&|\,', '', title) for title in no_result_titles]
no_result_dois = [title_doi_dict[title] for title in no_result_titles]

# %%
no_result_titles_transformed
# Out:
# ['Generation of Transfer Functions with Stochastic Search Technique',
#  'Automatic alignment of high-resolution multi-projector displays using an uncalibrated camera',
#  'Integrated control of distributed volume visualization through the World-Wide-Web',
#  'Color change and control of quantitative data display',
#  'MixMatch a construction kit for visualization',
#  'Visualizing causal effects in 4D space-time vector fields',
#  'Visualization for nonlinear engineering FEM analysis in manufacturing',
#  'Visualisation tools for semiconductor modelling software',
#  'Visualization of neutron scattering data using AVS',
#  "Fast analytical computation of Richard's smooth molecular surface",
#  'SSR-TVD Spatial Super-Resolution for Time-Varying Data Analysis and Visualization']

# %%
# build a df to show no result doi and title side by side, this is clearer
no_result_df = pd.DataFrame(columns = ['DOI', 'Title'])

# %%
no_result_df['DOI'] = no_result_dois
no_result_df['Title'] = no_result_titles

# %%
no_result_df
# Out:
#                            DOI  \
# 0   10.1109/VISUAL.1996.568113
# 1   10.1109/VISUAL.2000.885685
# 2   10.1109/VISUAL.1994.346342
# 3   10.1109/VISUAL.1992.235201
# 4   10.1109/VISUAL.1994.346305
# 5   10.1109/VISUAL.1991.175770
# 6   10.1109/VISUAL.1990.146412
# 7   10.1109/VISUAL.1991.175830
# 8   10.1109/VISUAL.1992.235180
# 9   10.1109/VISUAL.1993.398882
# 10   10.1109/tvcg.2020.3032123
#
#                                                                                            Title
# 0                              Generation of Transfer Functions with Stochastic Search Technique
# 1   Automatic alignment of high-resolution multi-projector displays using an uncalibrated camera
# 2              Integrated control of distributed volume visualization through the World-Wide-Web
# 3                                        Color, change, and control of quantitative data display
# 4                                                Mix&Match: a construction kit for visualization
# 5                                      Visualizing causal effects in 4D space-time vector fields
# 6                          Visualization for nonlinear engineering FEM analysis in manufacturing
# 7                                       Visualisation tools for semiconductor modelling software
# 8                                             Visualization of neutron scattering data using AVS
# 9                              Fast analytical computation of Richard's smooth molecular surface
# 10            SSR-TVD: Spatial Super-Resolution for Time-Varying Data Analysis and Visualization

# %% [markdown]
# ### among the 11 papers that are not able to be identified by title & doi seaerch:, four can be identified with manual adjustment
#
# #### Title is wrong:
#
# Generation of Transfer Functions with Stochastic Search Technique -> Generation of transfer functions with stochastic search techniques, 10.1109/VISUAL.1996.568113
#
# #### Title difficult to search
#
# <!-- - Interactive data analysis with nSpace2® -> Interactive data analysis with nSpace2
#  -->
# - Automatic alignment of high-resolution multi-projector displays using an uncalibrated camera -> Automatic alignment of high-resolution multi-projector display using an un-calibrated camera (https://openalex.org/W2170549385)
# - Mix&Match a construction kit for visualization, if I replace `&` with ' ' rather than '', it will be successful.
# <!-- -  PhylloTrees: Harnessing Nature's Phyllotactic Patterns for Tree Layout -> PhylloTrees: Harnessing Nature Phyllotactic Patterns for Tree Layout (*This is a little bit special. The title after -> is not that is shown on OpenAlex, but the query string that can get me to the target paper.*) -->
# - Fast analytical computation of Richard's smooth molecular surface -> Fast analytical computation of Richards's smooth molecular surface

# %% [markdown]
# ## Checking `vispd_openalex_match.csv`

# %%
df = pd.read_csv("../../data/interim/vispd_openalex_match_1.csv")
# df.Title != df['OpenAlex Title']) &

# %%
df.DOI[1]
df['OpenAlex DOI'][1]
df
# Out:
#       Year                         DOI  \
# 0     2011       10.1109/TVCG.2011.185
# 1     1991  10.1109/VISUAL.1991.175815
# 2     1990  10.1109/VISUAL.1990.146402
# 3     2006       10.1109/TVCG.2006.147
# 4     1997  10.1109/VISUAL.1997.663860
# ...    ...                         ...
# 3237  2021   10.1109/TVCG.2021.3084694
# 3238  2021   10.1109/TVCG.2021.3114777
# 3239  2021   10.1109/TVCG.2021.3071387
# 3240  2021   10.1109/TVCG.2020.3032984
# 3241  2021   10.1109/TVCG.2021.3114959
#
#                                                                                                 Title  \
# 0                                                                            D³ Data-Driven Documents
# 1     Tree-maps: a space-filling approach to the visualization of hierarchical information structures
# 2                             Parallel coordinates: a tool for visualizing multi-dimensional geometry
# 3                Hierarchical Edge Bundles: Visualization of Adjacency Relations in Hierarchical Data
# 4                                                ROAMing terrain: Real-time Optimally Adapting Meshes
# ...                                                                                               ...
# 3237                          Interactive Graph Construction for Graph-Based Semi-Supervised Learning
# 3238                                                         Visual Evaluation for Autonomous Driving
# 3239                                      Visual Cascade Analytics of Large-scale Spatiotemporal Data
# 3240                                   Understanding Missing Links in Bipartite Networks with MissBiN
# 3241                                                 Understanding Data Visualization Design Practice
#
#       OpenAlex Year                       OpenAlex ID  \
# 0            2011.0  https://openalex.org/W2135415614
# 1            1991.0  https://openalex.org/W2146872957
# 2            1990.0  https://openalex.org/W2034694694
# 3            2006.0  https://openalex.org/W2145640629
# 4            1997.0  https://openalex.org/W2532506824
# ...             ...                               ...
# 3237         2021.0  https://openalex.org/W3164124914
# 3238         2021.0  https://openalex.org/W3211221870
# 3239         2021.0  https://openalex.org/W3152147466
# 3240         2020.0  https://openalex.org/W3094173950
# 3241         2021.0  https://openalex.org/W3204423130
#
#                                                                                        OpenAlex Title  \
# 0                                                                            D³ Data-Driven Documents
# 1     Tree-maps: a space-filling approach to the visualization of hierarchical information structures
# 2                             Parallel coordinates: a tool for visualizing multi-dimensional geometry
# 3                Hierarchical Edge Bundles: Visualization of Adjacency Relations in Hierarchical Data
# 4                                                ROAMing terrain: real-time optimally adapting meshes
# ...                                                                                               ...
# 3237                          Interactive Graph Construction for Graph-Based Semi-Supervised Learning
# 3238                                                         Visual Evaluation for Autonomous Driving
# 3239                                      Visual Cascade Analytics of Large-scale Spatiotemporal Data
# 3240                                  Understanding Missing Links in Bipartite Networks with MissBiN.
# 3241                                                Understanding Data Visualization Design Practice.
#
#                                    OpenAlex DOI  \
# 0         https://doi.org/10.1109/tvcg.2011.185
# 1         https://doi.org/10.5555/949607.949654
# 2         https://doi.org/10.5555/949531.949588
# 3         https://doi.org/10.1109/tvcg.2006.147
# 4         https://doi.org/10.5555/266989.267028
# ...                                         ...
# 3237  https://doi.org/10.1109/tvcg.2021.3084694
# 3238  https://doi.org/10.1109/tvcg.2021.3114777
# 3239  https://doi.org/10.1109/tvcg.2021.3071387
# 3240  https://doi.org/10.1109/tvcg.2020.3032984
# 3241  https://doi.org/10.1109/tvcg.2021.3114959
#
#                                                        OpenAlex URL  \
# 0                             https://doi.org/10.1109/tvcg.2011.185
# 1                      https://ieeexplore.ieee.org/document/175815/
# 2     https://link.springer.com/chapter/10.1007/978-4-431-68057-4_3
# 3                             https://doi.org/10.1109/tvcg.2006.147
# 4                      https://ieeexplore.ieee.org/document/663860/
# ...                                                             ...
# 3237                      https://doi.org/10.1109/tvcg.2021.3084694
# 3238             https://ieeexplore.ieee.org/document/9597616/media
# 3239                      https://doi.org/10.1109/tvcg.2021.3071387
# 3240                      https://doi.org/10.1109/tvcg.2020.3032984
# 3241                      https://doi.org/10.1109/tvcg.2021.3114959
#
#                       OpenAlex Venue  \
# 0     https://openalex.org/V84775595
# 1                                NaN
# 2                                NaN
# 3     https://openalex.org/V84775595
# 4                                NaN
# ...                              ...
# 3237  https://openalex.org/V84775595
# 3238  https://openalex.org/V84775595
# 3239  https://openalex.org/V84775595
# 3240  https://openalex.org/V84775595
# 3241  https://openalex.org/V84775595
#
#                                               OpenAlex Journal  \
# 0     IEEE Transactions on Visualization and Computer Graphics
# 1                                           ieee visualization
# 2                                           ieee visualization
# 3     IEEE Transactions on Visualization and Computer Graphics
# 4                                           ieee visualization
# ...                                                        ...
# 3237  IEEE Transactions on Visualization and Computer Graphics
# 3238  IEEE Transactions on Visualization and Computer Graphics
# 3239  IEEE Transactions on Visualization and Computer Graphics
# 3240  IEEE Transactions on Visualization and Computer Graphics
# 3241  IEEE Transactions on Visualization and Computer Graphics
#
#                                      OpenAlex Publisher  OpenAlex First Page  \
# 0     Institute of Electrical and Electronics Engineers               2301.0
# 1                           IEEE Computer Society Press                284.0
# 2                           IEEE Computer Society Press                361.0
# 3     Institute of Electrical and Electronics Engineers                741.0
# 4                           IEEE Computer Society Press                 81.0
# ...                                                 ...                  ...
# 3237  Institute of Electrical and Electronics Engineers               3701.0
# 3238  Institute of Electrical and Electronics Engineers                  1.0
# 3239  Institute of Electrical and Electronics Engineers                  1.0
# 3240  Institute of Electrical and Electronics Engineers                  1.0
# 3241  Institute of Electrical and Electronics Engineers                  1.0
#
#       OpenAlex Last Page
# 0                 2309.0
# 1                  291.0
# 2                  378.0
# 3                  748.0
# 4                   88.0
# ...                  ...
# 3237              3716.0
# 3238                 1.0
# 3239                 1.0
# 3240                 1.0
# 3241                 1.0
#
# [3242 rows x 13 columns]

# %% [markdown]
# ## Looking into df, to prepare for string replacing

# %% [markdown]
# I wanted to see the part of the strings in the titles that I need to modify. The reason I did it is to see whether I want to replace part of the title instead of the whole of title (no special reasons, just to make the script look cleaner). To do that, I need to make sure there is only one paper with the specific part of string i want to replace.

# %%
df[df.Title.str.contains("Richard's")]
# Out:
#       Year                         DOI  \
# 2875  1993  10.1109/VISUAL.1993.398882
#
#                                                                   Title  \
# 2875  Fast analytical computation of Richard's smooth molecular surface
#
#       OpenAlex Year OpenAlex ID OpenAlex Title OpenAlex DOI OpenAlex URL  \
# 2875            NaN         NaN            NaN          NaN          NaN
#
#      OpenAlex Venue OpenAlex Journal OpenAlex Publisher  OpenAlex First Page  \
# 2875            NaN              NaN                NaN                  NaN
#
#       OpenAlex Last Page
# 2875                 NaN

# %%
df[df.Title.str.contains('Stochastic Search Technique')]
# Out:
#     Year                         DOI  \
# 93  1996  10.1109/VISUAL.1996.568113
#
#                                                                 Title  \
# 93  Generation of Transfer Functions with Stochastic Search Technique
#
#     OpenAlex Year OpenAlex ID OpenAlex Title OpenAlex DOI OpenAlex URL  \
# 93            NaN         NaN            NaN          NaN          NaN
#
#    OpenAlex Venue OpenAlex Journal OpenAlex Publisher  OpenAlex First Page  \
# 93            NaN              NaN                NaN                  NaN
#
#     OpenAlex Last Page
# 93                 NaN

# %%
df[df.Title.str.contains('displays using an uncalibrated camera')]
# Out:
#      Year                         DOI  \
# 262  2000  10.1109/VISUAL.2000.885685
#
#                                                                                             Title  \
# 262  Automatic alignment of high-resolution multi-projector displays using an uncalibrated camera
#
#      OpenAlex Year OpenAlex ID OpenAlex Title OpenAlex DOI OpenAlex URL  \
# 262            NaN         NaN            NaN          NaN          NaN
#
#     OpenAlex Venue OpenAlex Journal OpenAlex Publisher  OpenAlex First Page  \
# 262            NaN              NaN                NaN                  NaN
#
#      OpenAlex Last Page
# 262                 NaN

# %% [markdown]
# ### Replace all "'" or not
#
# I am thinking of two methods:
#
# - `.replace("Nature's", "Nature’s").replace("Richard's", "Richards's")` to replace only these two instances
#
# - `.replace("'", "’")` to replace all
#
# First all, I need to find out how many titles contain the string of "'":

# %%
titles_to_check = df[df.Title.str.contains("'")].Title.tolist()
len(titles_to_check)
# Out:
# 32

# %% [markdown]
# ## Checking the results where title queries were successful

# %%
# checking how many papers do not have openalex id; that is, how many failed. 
# i want to see whether the number match the total of no_result and no_match

df[df['OpenAlex ID'].isnull()].shape[0]

# Yes, it is correct
# Out:
# 11

# %%
# first, filter out those without openalex id
no_nan_df = df.dropna(subset=['OpenAlex ID'])
# create a new column based on DOI; the purpose is to compare it with OpenAlex DOI
no_nan_df = no_nan_df.assign(DOI_URL = [re.sub(r'^', 'https://doi.org/', doi) for doi in no_nan_df.DOI])
# then, show rows where both title and doi do not match
no_nan_df[(no_nan_df.Title.str.lower() != no_nan_df['OpenAlex Title'].str.lower()) & (
    no_nan_df['OpenAlex DOI'].str.lower() != no_nan_df['DOI_URL'].str.lower()
)]
# shape: (52, 14). There are 52 papers whose title AND DOI do not match with those on OpenAlex
# Out:
#       Year                          DOI  \
# 147   1999   10.1109/VISUAL.1999.809896
# 158   1991   10.1109/VISUAL.1991.175771
# 175   1998   10.1109/VISUAL.1998.745302
# 195   1993   10.1109/VISUAL.1993.398868
# 261   1993   10.1109/VISUAL.1993.398859
# 350   1991   10.1109/VISUAL.1991.175795
# 354   2003  10.1109/VISUAL.2003.1250401
# 389   1991   10.1109/VISUAL.1991.175789
# 414   2000   10.1109/VISUAL.2000.885739
# 523   1999   10.1109/VISUAL.1999.809871
# 564   1996   10.1109/VISUAL.1996.567807
# 573   1991   10.1109/VISUAL.1991.175777
# 643   1998   10.1109/VISUAL.1998.745315
# 704   1997   10.1109/VISUAL.1997.663909
# 807   2000   10.1109/VISUAL.2000.885697
# 862   2001   10.1109/VISUAL.2001.964504
# 969   1997   10.1109/VISUAL.1997.663910
# 1240  1996   10.1109/VISUAL.1996.568128
# 1341  1997   10.1109/VISUAL.1997.663923
# 1389  2011    10.1109/VAST.2011.6102441
# 1409  2000   10.1109/VISUAL.2000.885732
# 1437  2001   10.1109/VISUAL.2001.964522
# 1691  2005  10.1109/VISUAL.2005.1532812
# 1842  2001   10.1109/INFVIS.2001.963282
# 1931  1995   10.1109/VISUAL.1995.480804
# 1950  2005  10.1109/VISUAL.2005.1532847
# 2212  2000   10.1109/VISUAL.2000.885738
# 2275  1992   10.1109/VISUAL.1992.235194
# 2333  1993   10.1109/VISUAL.1993.398865
# 2334  1993   10.1109/VISUAL.1993.398866
# 2395  1993   10.1109/VISUAL.1993.398867
# 2582  1992   10.1109/VISUAL.1992.235181
# 2583  1992   10.1109/VISUAL.1992.235195
# 2657  2000   10.1109/VISUAL.2000.885719
# 2723  1991   10.1109/VISUAL.1991.175816
# 2872  1993   10.1109/VISUAL.1993.398861
# 2873  1993   10.1109/VISUAL.1993.398872
# 2879  1994   10.1109/VISUAL.1994.346292
# 2881  1994   10.1109/VISUAL.1994.346295
# 2882  1994   10.1109/VISUAL.1994.346297
# 2885  1994   10.1109/VISUAL.1994.346301
# 2899  1999   10.1109/VISUAL.1999.809913
# 2902  2001   10.1109/VISUAL.2001.964546
# 2908  2003  10.1109/VISUAL.2003.1250379
# 2910  2003  10.1109/VISUAL.2003.1250404
# 2913  2014    10.1109/TVCG.2014.2346442
# 2917  2020    10.1109/TVCG.2020.3028948
# 2991  2020    10.1109/TVCG.2020.3030363
# 3057  2020    10.1109/TVCG.2020.3030364
# 3128  2021    10.1109/tvcg.2021.3114782
# 3185  2021    10.1109/tvcg.2021.3114783
# 3231  2021    10.1109/TVCG.2021.3114842
#
#                                                                                                                                    Title  \
# 147                                                               The "Parallel Vectors" operator-a vector field visualization primitive
# 158                                       The virtual windtunnel: An environment for the exploration of three-dimensional unsteady flows
# 175                                                                         TOPIC ISLANDS TM - a wavelet-based text visualization system
# 195                                                                                                               Geometric optimization
# 261                                                                     HyperSlice - Visualization of Scalar Functions of Many Variables
# 350                                Color icons: merging color and texture perception for integrated visualization of multiple parameters
# 354                                                                                                                  Video visualization
# 389                                                                    The stream polygon: A technique for 3D vector field visualization
# 414           WEAVE: a system for visually linking 3-D and statistical visualizations applied to cardiac simulation and measurement data
# 523                                                                             Image graphs-a novel approach to visual data exploration
# 564                                                                                                                      Volume tracking
# 573                                                                               Fast rotation of volume data on parallel architectures
# 643                                                                                                 Simplification of tetrahedral meshes
# 704                                                                             Controlled simplification of genus for polygonal models
# 807                                                                                      Two-level volume rendering - fusing MIP and DVR
# 862                                                                                                                  Connectivity shapes
# 969                                                                     Vortex identification-applications in aerodynamics: a case study
# 1240  Virtual Workbench-a non-immersive virtual environment for visualizing and interacting with 3D objects for scientific visualization
# 1341                                                        Pearls found on the way to the ideal interface for scanned probe microscopes
# 1389                           Orion: A system for modeling, transformation and visualization of multidimensional heterogeneous networks
# 1409                                                                         Mastering interactive virtual bronchioscopy on a low-end PC
# 1437                                                                       RTVR-a flexible Java library for interactive volume rendering
# 1691                                                                                             High dynamic range volume visualization
# 1842                                                                                                                      Graph sketches
# 1931                                                                                                                       Space walking
# 1950                                                                              Profile Flags: a novel metaphor for probing of T₂ maps
# 2212                                  Vector fields simplification-a case study of visualizing climate modeling and simulation data sets
# 2275                                                                                                                      Volume warping
# 2333  DIVIDE: Distributed visual display of the execution of asynchronous, distributed algorithms on loosely-coupled parallel processors
# 2334                                                                                      Performance visualization of parallel programs
# 2395                                                        Orientation maps: Techniques for visualizing rotations (A  Consumer's Guide)
# 2582                                                                                                            Visualizing the Universe
# 2583                                                                                                        Network video device control
# 2657                                                                                                                 Polyhedral modeling
# 2723                                                                                            How shall we connect our software tools?
# 2872                                                                    Developing modular application builders to exploit MIMD parallel
# 2873                                                         Towards a texture naming system: Identifying relevant dimensions of texture
# 2879                                                                              Visualization of an electric power transmission system
# 2881                                                                         Observing a volume rendered fetus within a pregnant patient
# 2882                                                                            Visualization of mesoscale flow features in ocean basins
# 2885                                                                                             Tokamak plasma turbulence visualization
# 2899                                                                Digital design of a surgical simulator for interventional MR imaging
# 2902                                                          Chromatin decondensation: case study of tracking features in confocal data
# 2908                                                                                                                            HyperLIC
# 2910                                                                                            Hierarchical splatting of scattered data
# 2913                                                                                                                         Escape Maps
# 2917                                       A Generic Framework and Library for Exploration of Small Multiples through Interactive Piling
# 2991                                                 Improving the Usability of Virtual Reality Neuron Tracing with Topological Elements
# 3057                                              Supporting the Problem-Solving Loop: Designing Highly Interactive Optimisation Systems
# 3128                           An Automated Approach to Reasoning About Task-Oriented Visualization Insights in Responsive Visualization
# 3185                                                    The Weighted Average Illusion: Biases in Perceived Mean Position in Scatterplots
# 3231                                                                                                           Visualization Equilibrium
#
#       OpenAlex Year                       OpenAlex ID  \
# 147          1999.0  https://openalex.org/W2095105262
# 158          1991.0  https://openalex.org/W2114975239
# 175          1998.0  https://openalex.org/W2136452290
# 195          1988.0  https://openalex.org/W2100440346
# 261          1993.0  https://openalex.org/W2103111128
# 350          1991.0  https://openalex.org/W1991928089
# 354          1997.0  https://openalex.org/W2104113200
# 389          1991.0  https://openalex.org/W2077014479
# 414          2000.0  https://openalex.org/W2089875636
# 523          1999.0  https://openalex.org/W2018246367
# 564          1998.0  https://openalex.org/W2013043910
# 573          1991.0  https://openalex.org/W2128435165
# 643          2000.0  https://openalex.org/W1996994046
# 704          1997.0  https://openalex.org/W2155412154
# 807          2000.0  https://openalex.org/W1990028735
# 862          2007.0  https://openalex.org/W2006312249
# 969          1997.0  https://openalex.org/W2129302988
# 1240         1996.0  https://openalex.org/W2131777532
# 1341         1997.0  https://openalex.org/W2141871926
# 1389         2014.0  https://openalex.org/W2068966762
# 1409         2000.0  https://openalex.org/W1993673415
# 1437         2001.0  https://openalex.org/W2150898819
# 1691         2006.0  https://openalex.org/W2147842609
# 1842         2012.0  https://openalex.org/W1997010704
# 1931         2005.0   https://openalex.org/W202456592
# 1950         2005.0  https://openalex.org/W2143277319
# 2212         2000.0  https://openalex.org/W2020079884
# 2275         2018.0  https://openalex.org/W2963782415
# 2333         1994.0  https://openalex.org/W2052097245
# 2334         1994.0  https://openalex.org/W1514652597
# 2395         1993.0  https://openalex.org/W2140793785
# 2582         2010.0  https://openalex.org/W1531770652
# 2583         2016.0  https://openalex.org/W2308940062
# 2657         2009.0  https://openalex.org/W2167356151
# 2723         1991.0  https://openalex.org/W2115973673
# 2872         1993.0  https://openalex.org/W2133430557
# 2873         1996.0  https://openalex.org/W2095363539
# 2879         1994.0  https://openalex.org/W2147491968
# 2881         1994.0  https://openalex.org/W2136046800
# 2882         1994.0  https://openalex.org/W2099243101
# 2885         1994.0  https://openalex.org/W2088778374
# 2899         1999.0  https://openalex.org/W2002564039
# 2902         2001.0  https://openalex.org/W2008347373
# 2908         2006.0  https://openalex.org/W2365704339
# 2910         2004.0  https://openalex.org/W1998404833
# 2913         2005.0  https://openalex.org/W2087325044
# 2917         2020.0  https://openalex.org/W3023951087
# 2991         2020.0  https://openalex.org/W3083399682
# 3057         2020.0  https://openalex.org/W3083286135
# 3128         2021.0  https://openalex.org/W3186894540
# 3185         2021.0  https://openalex.org/W3202148648
# 3231         2018.0  https://openalex.org/W2806848223
#
#                                                                                                                                OpenAlex Title  \
# 147                                                                   The “parallel vectors” operator: a vector field visualization primitive
# 158                                             The virtual windtunnel-an environment for the exploration of three-dimensional unsteady flows
# 175                                                                           TOPIC ISLANDS/sup TM/-a wavelet-based text visualization system
# 195                                                                                       Geometric Algorithms and Combinatorial Optimization
# 261                                                                           HyperSlice: visualization of scalar functions of many variables
# 350                                      Color icons-merging color and texture perception for integrated visualization of multiple parameters
# 354                                                       Video visualization for compact presentation and fast browsing of pictorial content
# 389                                                                          The stream polygon-a technique for 3D vector field visualization
# 414               WEAVE: a system for visually linking 3-D and statistical visualizations, applied to cardiac simulation and measurement data
# 523                                                                                  Image graphs—a novel approach to visual data exploration
# 564                                                                                                            Reconstructing Volume Tracking
# 573                                                                               Fast rotation of volume data on data parallel architectures
# 643                                                                       Simplification of Tetrahedral meshes with accurate error evaluation
# 704                                                                                   Controlled simplification of genus for polygonal models
# 807                                                                                           Two-level volume rendering — fusing MIP and DVR
# 862                                              Network structure of cerebral cortex shapes functional connectivity on multiple time scales.
# 969                                                                          Vortex identification—applications in aerodynamics: a case study
# 1240     Virtual workbench - a non-immersive virtual environment for visualizing and interacting with 3D objects for scientific visualization
# 1341                                                             Pearls found on the way to the ideal interface for scanned-probe microscopes
# 1389                               Orion: A system for modeling, transformation and visualization of multidimensional heterogeneous networks:
# 1409                                                                              Mastering interactive virtual Bronchioscopy on a Low—end PC
# 1437                                                                           RTVR: a flexible java library for interactive volume rendering
# 1691                                                                                      HDR VolVis: high dynamic range volume visualization
# 1842                                                                                  Graph sketches: sparsification, spanners, and subgraphs
# 1931                                         Increasing walking: How important is distance to, attractiveness, and size of public open space?
# 1950                                                                             Profile Flags: a novel metaphor for probing of T/sub 2/ maps
# 2212                                     Vector fields simplification — a case study of visualizing climate modeling and simulation data sets
# 2275                                                                   PWC-Net: CNNs for Optical Flow Using Pyramid, Warping, and Cost Volume
# 2333       DIVIDE: Distributed visual display of the execution of asynchronous, distributed algorithms on loosely coupled parallel processors
# 2334                                                                  Performance Visualization of Parallel Programs - The PARvis Environment
# 2395                                                              Orientation maps: techniques for visualizing rotations (a consumer's guide)
# 2582                                                                                                       Uniview - Visualizing the Universe
# 2583  Unified low-layer power allocation and high-layer mode control for video delivery in device-to-device network with multi-antenna relays
# 2657                                                                                           Efficient Polyhedral Modeling from Silhouettes
# 2723                                                                                                  How shall we connect our software tools
# 2872                                                               Developing modular application builders to exploit MIMD parallel resources
# 2873                                                             Towards a texture naming system: identifying relevant dimensions of texture.
# 2879                                                                       Case study: visualization of an electric power transmission system
# 2881                                                                  Case study: observing a volume rendered fetus within a pregnant patient
# 2882                                                                     Case study: visualization of mesoscale flow features in ocean basins
# 2885                                                                                      Case study: tokamak plasma turbulence visualization
# 2899                                                        Digital design of a surgical simulator for interventional MR imaging (case study)
# 2902                                                             Chromatin decondensation: a case study of tracking features in confocal data
# 2908                                        Blow-up of solutions to initial boundary value problem for a class of nonlinear hyperlic equation
# 2910                                                                                              Hierarchical splatting of scattered 4D data
# 2913                                                                             The escape trichotomy for singularly perturbed rational maps
# 2917                                           A Generic Framework and Library for Exploration of Small Multiples through Interactive Piling.
# 2991                                                     Improving the Usability of Virtual Reality Neuron Tracing with Topological Elements.
# 3057                                                  Supporting the Problem-Solving Loop: Designing Highly Interactive Optimisation Systems.
# 3128                                              An Automated Approach to Reasoning About Task-Oriented Insights in Responsive Visualization
# 3185                                                        The Weighted Average Illusion: Biases in Perceived Mean Position in Scatterplots.
# 3231                                                            Atomic visualization of a non-equilibrium sodiation pathway in copper sulfide
#
#                                       OpenAlex DOI  \
# 147          https://doi.org/10.5555/319351.319420
# 158          https://doi.org/10.5555/949607.949612
# 175          https://doi.org/10.5555/288216.288247
# 195                                            NaN
# 261          https://doi.org/10.5555/949845.949871
# 350          https://doi.org/10.5555/949607.949634
# 354              https://doi.org/10.1109/76.633496
# 389          https://doi.org/10.5555/949607.949628
# 414          https://doi.org/10.5555/375213.375311
# 523          https://doi.org/10.5555/319351.319360
# 564         https://doi.org/10.1006/jcph.1998.5906
# 573          https://doi.org/10.5555/949607.949616
# 643          https://doi.org/10.5555/375213.375222
# 704          https://doi.org/10.5555/266989.267109
# 807          https://doi.org/10.5555/375213.375244
# 862        https://doi.org/10.1073/pnas.0701519104
# 969          https://doi.org/10.5555/266989.267110
# 1240         https://doi.org/10.5555/244979.245631
# 1341         https://doi.org/10.5555/266989.267123
# 1389      https://doi.org/10.1177/1473871612462152
# 1409         https://doi.org/10.5555/375213.375298
# 1437         https://doi.org/10.5555/601671.601714
# 1691          https://doi.org/10.1109/tvcg.2006.72
# 1842       https://doi.org/10.1145/2213556.2213560
# 1931  https://doi.org/10.1016/j.amepre.2004.10.018
# 1950           https://doi.org/10.1109/vis.2005.81
# 2212         https://doi.org/10.5555/375213.375309
# 2275       https://doi.org/10.1109/cvpr.2018.00931
# 2333  https://doi.org/10.1016/0097-8493(94)90012-4
# 2334                                           NaN
# 2395         https://doi.org/10.5555/949845.949881
# 2582          https://doi.org/10.2312/ega.20101005
# 2583     https://doi.org/10.1049/iet-com.2015.0889
# 2657        https://doi.org/10.1109/tpami.2008.104
# 2723         https://doi.org/10.5555/949607.949655
# 2872         https://doi.org/10.5555/949845.949873
# 2873  https://doi.org/10.1016/0042-6989(95)00202-2
# 2879         https://doi.org/10.5555/951087.951160
# 2881         https://doi.org/10.5555/951087.951156
# 2882         https://doi.org/10.5555/951087.951153
# 2885         https://doi.org/10.5555/951087.951148
# 2899         https://doi.org/10.5555/319351.319437
# 2902         https://doi.org/10.5555/601671.601744
# 2908                                           NaN
# 2910            https://doi.org/10.1109/mcg.2004.7
# 2913     https://doi.org/10.1512/iumj.2005.54.2615
# 2917                                           NaN
# 2991                                           NaN
# 3057                                           NaN
# 3128                                           NaN
# 3185                                           NaN
# 3231    https://doi.org/10.1038/s41467-018-03322-9
#
#                                                                                     OpenAlex URL  \
# 147            https://dblp.uni-trier.de/db/conf/visualization/visualization1999.html#PeikertR99
# 158                                                  http://ieeexplore.ieee.org/document/175771/
# 175                                                   https://doi.org/10.1109/VISUAL.1998.745302
# 195                                                         https://ci.nii.ac.jp/ncid/BA03567922
# 261                                                   https://doi.org/10.1109/VISUAL.1993.398859
# 350           https://dblp.uni-trier.de/db/conf/visualization/visualization1991.html#Levkowitz91
# 354                                                            https://doi.org/10.1109/76.633496
# 389                                                 https://dl.acm.org/doi/10.5555/949607.949628
# 414           https://dblp.uni-trier.de/db/conf/visualization/visualization2000.html#GreshRWSY00
# 523                   http://dblp.uni-trier.de/db/conf/visualization/visualization1999.html#Ma99
# 564                                                       https://doi.org/10.1006/jcph.1998.5906
# 573                                                  http://ieeexplore.ieee.org/document/175777/
# 643                                                  http://ieeexplore.ieee.org/document/885680/
# 704                                 https://www.cs.umd.edu/projects/gvil/papers/elsana_vis97.pdf
# 807           https://dblp.uni-trier.de/db/conf/visualization/visualization2000.html#HauserMBG00
# 862                                                      https://doi.org/10.1073/pnas.0701519104
# 969          https://dblp.uni-trier.de/db/conf/visualization/visualization1997.html#KenwrightH97
# 1240  http://dblp.uni-trier.de/db/conf/visualization/visualization1996.html#ObeysekareWDRRGRLS96
# 1341                   https://www.cs.unc.edu/~taylorr/cyberinfrastructure/1997vis97_reprint.pdf
# 1389                                                    https://doi.org/10.1177/1473871612462152
# 1409                         https://www.cg.tuwien.ac.at/research/vis/vismed/EndoWeb/endoweb.pdf
# 1437                                                 http://ieeexplore.ieee.org/document/964522/
# 1691                                                        https://doi.org/10.1109/tvcg.2006.72
# 1842                                                     https://doi.org/10.1145/2213556.2213560
# 1931                                                https://doi.org/10.1016/j.amepre.2004.10.018
# 1950                                                         https://doi.org/10.1109/vis.2005.81
# 2212                     http://yadda.icm.edu.pl/yadda/element/bwmeta1.element.ieee-000000885738
# 2275                                                     https://doi.org/10.1109/cvpr.2018.00931
# 2333                                                https://doi.org/10.1016/0097-8493(94)90012-4
# 2334                                                   https://juser.fz-juelich.de/record/190272
# 2395                                                https://dl.acm.org/doi/10.5555/949845.949881
# 2582                               https://diglib.eg.org:443/handle/10.2312/ega.20101005.037-043
# 2583                                                   https://doi.org/10.1049/iet-com.2015.0889
# 2657                                                      https://doi.org/10.1109/tpami.2008.104
# 2723             https://dblp.uni-trier.de/db/conf/visualization/visualization1991.html#Grosse91
# 2872                       https://surface.syr.edu/cgi/viewcontent.cgi?article=1074&context=npac
# 2873                                                https://doi.org/10.1016/0042-6989(95)00202-2
# 2879                                                  https://doi.org/10.1109/VISUAL.1994.346292
# 2881                                               https://www.cs.unc.edu/techreports/94-034.pdf
# 2882         https://dblp.uni-trier.de/db/conf/visualization/visualization1994.html#JohannsenM94
# 2885            https://dblp.uni-trier.de/db/conf/visualization/visualization1994.html#ParkerS94
# 2899                                                https://dl.acm.org/doi/10.5555/319351.319437
# 2902                                                 http://ieeexplore.ieee.org/document/964546/
# 2908                               https://en.cnki.com.cn/Article_en/CJFDTOTAL-ZKSG200602005.htm
# 2910                                                          https://doi.org/10.1109/mcg.2004.7
# 2913                                                   https://doi.org/10.1512/iumj.2005.54.2615
# 2917                                                        https://arxiv.org/pdf/2005.00595.pdf
# 2991                                                            https://arxiv.org/abs/2009.01891
# 3057                                                        https://arxiv.org/pdf/2009.03163.pdf
# 3128                                                        https://arxiv.org/pdf/2107.08141.pdf
# 3185                                                            https://arxiv.org/abs/2108.03766
# 3231                                                  https://doi.org/10.1038/s41467-018-03322-9
#
#                         OpenAlex Venue  \
# 147                                NaN
# 158                                NaN
# 175                                NaN
# 195                                NaN
# 261                                NaN
# 350                                NaN
# 354    https://openalex.org/V115173108
# 389                                NaN
# 414                                NaN
# 523                                NaN
# 564    https://openalex.org/V148709879
# 573                                NaN
# 643                                NaN
# 704                                NaN
# 807                                NaN
# 862    https://openalex.org/V125754415
# 969                                NaN
# 1240                               NaN
# 1341                               NaN
# 1389    https://openalex.org/V55152591
# 1409                               NaN
# 1437                               NaN
# 1691    https://openalex.org/V84775595
# 1842                               NaN
# 1931   https://openalex.org/V195759676
# 1950                               NaN
# 2212                               NaN
# 2275                               NaN
# 2333    https://openalex.org/V94821547
# 2334                               NaN
# 2395                               NaN
# 2582                               NaN
# 2583    https://openalex.org/V85427048
# 2657   https://openalex.org/V199944782
# 2723                               NaN
# 2872                               NaN
# 2873    https://openalex.org/V68719679
# 2879                               NaN
# 2881                               NaN
# 2882                               NaN
# 2885                               NaN
# 2899                               NaN
# 2902                               NaN
# 2908  https://openalex.org/V2764756576
# 2910   https://openalex.org/V105380075
# 2913   https://openalex.org/V196210972
# 2917  https://openalex.org/V2595899084
# 2991  https://openalex.org/V2596830251
# 3057  https://openalex.org/V2595899084
# 3128  https://openalex.org/V2595899084
# 3185  https://openalex.org/V2595899084
# 3231    https://openalex.org/V64187185
#
#                                                                      OpenAlex Journal  \
# 147                                                                ieee visualization
# 158                                                                ieee visualization
# 175                                                                ieee visualization
# 195                                                                               NaN
# 261                                                                ieee visualization
# 350                                                                ieee visualization
# 354                    IEEE Transactions on Circuits and Systems for Video Technology
# 389                                                                ieee visualization
# 414                                                                ieee visualization
# 523                                                                ieee visualization
# 564                                                  Journal of Computational Physics
# 573                                                                ieee visualization
# 643                                                                ieee visualization
# 704                                                                ieee visualization
# 807                                                                ieee visualization
# 862   Proceedings of the National Academy of Sciences of the United States of America
# 969                                                                ieee visualization
# 1240                                                               ieee visualization
# 1341                                                               ieee visualization
# 1389                                                        Information Visualization
# 1409                                                               ieee visualization
# 1437                                                               ieee visualization
# 1691                         IEEE Transactions on Visualization and Computer Graphics
# 1842                                      symposium on principles of database systems
# 1931                                          American Journal of Preventive Medicine
# 1950                                                               ieee visualization
# 2212                                                               ieee visualization
# 2275                                          computer vision and pattern recognition
# 2333                                                             Computers & Graphics
# 2334                                  Intel Supercomputer Users Group Conference 1994
# 2395                                                               ieee visualization
# 2582                                                                     eurographics
# 2583                                                               Iet Communications
# 2657                   IEEE Transactions on Pattern Analysis and Machine Intelligence
# 2723                                                               ieee visualization
# 2872                                                               ieee visualization
# 2873                                                                  Vision Research
# 2879                                                               ieee visualization
# 2881                                                               ieee visualization
# 2882                                                               ieee visualization
# 2885                                                               ieee visualization
# 2899                                                               ieee visualization
# 2902                                                               ieee visualization
# 2908                                             Journal of Zhoukou Normal University
# 2910                                          IEEE Computer Graphics and Applications
# 2913                                           Indiana University Mathematics Journal
# 2917                                                arXiv: Human-Computer Interaction
# 2991                                                                  arXiv: Graphics
# 3057                                                arXiv: Human-Computer Interaction
# 3128                                                arXiv: Human-Computer Interaction
# 3185                                                arXiv: Human-Computer Interaction
# 3231                                                            Nature Communications
#
#                                      OpenAlex Publisher  OpenAlex First Page  \
# 147                         IEEE Computer Society Press                263.0
# 158                         IEEE Computer Society Press                 17.0
# 175                         IEEE Computer Society Press                189.0
# 195                                                 NaN                  NaN
# 261                               IEEE Computer Society                119.0
# 350                         IEEE Computer Society Press                164.0
# 354   Institute of Electrical and Electronics Engineers                771.0
# 389                         IEEE Computer Society Press                126.0
# 414                         IEEE Computer Society Press                489.0
# 523                         IEEE Computer Society Press                 81.0
# 564                                            Elsevier                112.0
# 573                         IEEE Computer Society Press                 50.0
# 643                         IEEE Computer Society Press                 85.0
# 704                         IEEE Computer Society Press                403.0
# 807                         IEEE Computer Society Press                211.0
# 862     Proceedings of the National Academy of Sciences              10240.0
# 969                         IEEE Computer Society Press                413.0
# 1240                        IEEE Computer Society Press                345.0
# 1341                        IEEE Computer Society Press                467.0
# 1389                                               SAGE                111.0
# 1409                        IEEE Computer Society Press                461.0
# 1437                              IEEE Computer Society                279.0
# 1691  Institute of Electrical and Electronics Engineers                433.0
# 1842                                                ACM                  5.0
# 1931                                           Elsevier                169.0
# 1950                                               IEEE                599.0
# 2212                        IEEE Computer Society Press                485.0
# 2275                                               IEEE               8934.0
# 2333                                           Elsevier                849.0
# 2334               Concurrent Supercomputing Consortium                  NaN
# 2395                              IEEE Computer Society                183.0
# 2582                           Eurographics Association                 37.0
# 2583                Institution of Electrical Engineers               1196.0
# 2657  Institute of Electrical and Electronics Engineers                414.0
# 2723                        IEEE Computer Society Press                292.0
# 2872                              IEEE Computer Society                134.0
# 2873                                           Elsevier               1649.0
# 2879                        IEEE Computer Society Press                379.0
# 2881                        IEEE Computer Society Press                364.0
# 2882                        IEEE Computer Society Press                355.0
# 2885                        IEEE Computer Society Press                337.0
# 2899                        IEEE Computer Society Press                393.0
# 2902                              IEEE Computer Society                441.0
# 2908                                                NaN                  NaN
# 2910  Institute of Electrical and Electronics Engineers                 64.0
# 2913             Indiana University Mathematics Journal               1621.0
# 2917                                                NaN                  NaN
# 2991                                                NaN                  NaN
# 3057                                                NaN                  NaN
# 3128                                                NaN                  NaN
# 3185                                                NaN                  NaN
# 3231                                    Springer Nature                922.0
#
#       OpenAlex Last Page                                      DOI_URL
# 147                270.0   https://doi.org/10.1109/VISUAL.1999.809896
# 158                 24.0   https://doi.org/10.1109/VISUAL.1991.175771
# 175                196.0   https://doi.org/10.1109/VISUAL.1998.745302
# 195                  NaN   https://doi.org/10.1109/VISUAL.1993.398868
# 261                125.0   https://doi.org/10.1109/VISUAL.1993.398859
# 350                170.0   https://doi.org/10.1109/VISUAL.1991.175795
# 354                785.0  https://doi.org/10.1109/VISUAL.2003.1250401
# 389                132.0   https://doi.org/10.1109/VISUAL.1991.175789
# 414                492.0   https://doi.org/10.1109/VISUAL.2000.885739
# 523                 88.0   https://doi.org/10.1109/VISUAL.1999.809871
# 564                152.0   https://doi.org/10.1109/VISUAL.1996.567807
# 573                 57.0   https://doi.org/10.1109/VISUAL.1991.175777
# 643                 92.0   https://doi.org/10.1109/VISUAL.1998.745315
# 704                410.0   https://doi.org/10.1109/VISUAL.1997.663909
# 807                218.0   https://doi.org/10.1109/VISUAL.2000.885697
# 862              10245.0   https://doi.org/10.1109/VISUAL.2001.964504
# 969                416.0   https://doi.org/10.1109/VISUAL.1997.663910
# 1240               349.0   https://doi.org/10.1109/VISUAL.1996.568128
# 1341               470.0   https://doi.org/10.1109/VISUAL.1997.663923
# 1389               133.0    https://doi.org/10.1109/VAST.2011.6102441
# 1409               464.0   https://doi.org/10.1109/VISUAL.2000.885732
# 1437               286.0   https://doi.org/10.1109/VISUAL.2001.964522
# 1691               445.0  https://doi.org/10.1109/VISUAL.2005.1532812
# 1842                14.0   https://doi.org/10.1109/INFVIS.2001.963282
# 1931               176.0   https://doi.org/10.1109/VISUAL.1995.480804
# 1950               606.0  https://doi.org/10.1109/VISUAL.2005.1532847
# 2212               488.0   https://doi.org/10.1109/VISUAL.2000.885738
# 2275              8943.0   https://doi.org/10.1109/VISUAL.1992.235194
# 2333               859.0   https://doi.org/10.1109/VISUAL.1993.398865
# 2334                 NaN   https://doi.org/10.1109/VISUAL.1993.398866
# 2395               188.0   https://doi.org/10.1109/VISUAL.1993.398867
# 2582                43.0   https://doi.org/10.1109/VISUAL.1992.235181
# 2583              1205.0   https://doi.org/10.1109/VISUAL.1992.235195
# 2657               427.0   https://doi.org/10.1109/VISUAL.2000.885719
# 2723               296.0   https://doi.org/10.1109/VISUAL.1991.175816
# 2872               141.0   https://doi.org/10.1109/VISUAL.1993.398861
# 2873              1669.0   https://doi.org/10.1109/VISUAL.1993.398872
# 2879               381.0   https://doi.org/10.1109/VISUAL.1994.346292
# 2881               368.0   https://doi.org/10.1109/VISUAL.1994.346295
# 2882               358.0   https://doi.org/10.1109/VISUAL.1994.346297
# 2885               340.0   https://doi.org/10.1109/VISUAL.1994.346301
# 2899               396.0   https://doi.org/10.1109/VISUAL.1999.809913
# 2902               444.0   https://doi.org/10.1109/VISUAL.2001.964546
# 2908                 NaN  https://doi.org/10.1109/VISUAL.2003.1250379
# 2910                72.0  https://doi.org/10.1109/VISUAL.2003.1250404
# 2913              1634.0    https://doi.org/10.1109/TVCG.2014.2346442
# 2917                 NaN    https://doi.org/10.1109/TVCG.2020.3028948
# 2991                 NaN    https://doi.org/10.1109/TVCG.2020.3030363
# 3057                 NaN    https://doi.org/10.1109/TVCG.2020.3030364
# 3128                 NaN    https://doi.org/10.1109/tvcg.2021.3114782
# 3185                 NaN    https://doi.org/10.1109/tvcg.2021.3114783
# 3231               922.0    https://doi.org/10.1109/TVCG.2021.3114842

# %%
# I manually checked the above results, and found that 17 papers are wrong mathces. Among these 17,
# only two cannot be identified on OpenAlex; the remaining 15 can be identified via
# a different index in title query or simply using doi query
wrong_match_dois = [
    '10.1109/VISUAL.1993.398868', # Geometric optimization, INDEX: [5]
    '10.1109/VISUAL.2003.1250401', # video visualization, DOI searchable
#     '10.1109/TVCG.2014.2346922', # #fluxflow, fixable by deleteting #
    '10.1109/VISUAL.1996.567807', # Volume tracking, INDEX: [6]
    '10.1109/VISUAL.1998.745315', # simplication of tetrahedral meshes, DOI searchable
    '10.1109/VISUAL.2001.964504', # connectivity shapes, INDEX: [2]
    '10.1109/VISUAL.2005.1532812', # High dynamic range volume visualization, INDEX: [1]
    '10.1109/INFVIS.2001.963282', #graph sketches, INDEX: [1]
    '10.1109/VISUAL.1995.480804', # space walking, DOI searchable
    '10.1109/VISUAL.1992.235194', # volumn warping, INDEX: [3]
    '10.1109/VISUAL.1993.398866', # performance visualization of parallel programs, INDEX: [3]
    '10.1109/VISUAL.1992.235181', # Visualizing the Universe, INDEX: [1]
    '10.1109/VISUAL.1992.235195', # Network video device control, INDEX: [1]
    '10.1109/VISUAL.2000.885719', # Polyhedral modeling, DOI searchable
    '10.1109/VISUAL.2003.1250379', #hyperlic
    '10.1109/VISUAL.2003.1250404', # Hierarchical splatting of scattered data, doi searchable
    '10.1109/TVCG.2014.2346442', #escape maps
#     '10.1109/TVCG.2021.3114849': #interactive data comics, doi searchable
    '10.1109/TVCG.2021.3114842', #Visualization Equilibrium, doi searchable
]

# %% [markdown]
# Another worth mentioning is that "#FluxFlow: Visual Analysis of Anomalous Information Spreading on Social Media" can be easily searched on OpenAlex if I remove the "#" in the beginning.

# %% [markdown]
# 56 papers have different title AND DOI. Among these, 17 are indeed different. Among these 17, only two, namely, HyperLIC and Escape Maps are not searchable. The remaining 15 can be found by a different index in title query results, or simply through DOI search.

# %%
to_query_by_doi = [
        '10.1109/VISUAL.2003.1250401',
        '10.1109/VISUAL.1998.745315',
        '10.1109/VISUAL.1995.480804',
        '10.1109/VISUAL.2000.885719',
        '10.1109/TVCG.2021.3114842',
        '10.1109/TVCG.2021.3114849',
        '10.1109/VISUAL.2003.1250404',
    ]

# %%
special_result_index_dict = {
	    '10.1109/VISUAL.1993.398868': 5,
	    '10.1109/VISUAL.1996.567807': 6,
	    '10.1109/VISUAL.2001.964504': 2,
	    '10.1109/VISUAL.2005.1532812': 1,
	    '10.1109/INFVIS.2001.963282': 1,
	    '10.1109/VISUAL.1992.235194': 3,
	    '10.1109/VISUAL.1993.398866': 3,
	    '10.1109/VISUAL.1992.235181': 1,
	    '10.1109/VISUAL.1992.235195': 1,
	}

# %%
list(special_result_index_dict.keys())
# Out:
# ['10.1109/VISUAL.1993.398868',
#  '10.1109/VISUAL.1996.567807',
#  '10.1109/VISUAL.2001.964504',
#  '10.1109/VISUAL.2005.1532812',
#  '10.1109/INFVIS.2001.963282',
#  '10.1109/VISUAL.1992.235194',
#  '10.1109/VISUAL.1993.398866',
#  '10.1109/VISUAL.1992.235181',
#  '10.1109/VISUAL.1992.235195']

# %%
special_result_index_dict['10.1109/VISUAL.1996.567807']
# Out:
# 6

# %% [markdown]
# ### Checking '#'
#
# Later, I will replace `'#'` with `''`. To do that, I need to check how many papers have "#" and whether they can still be identified on OpenAlex once "#" is removed.
#
# The answer is yes. I manually tried, and they can be identified.

# %%
df[df.Title.str.contains('#')]
# Out:
#      Year                        DOI  \
# 518  2014  10.1109/TVCG.2014.2346922
#
#                                                                              Title  \
# 518  #FluxFlow: Visual Analysis of Anomalous Information Spreading on Social Media
#
#      OpenAlex Year                       OpenAlex ID  \
# 518         1959.0  https://openalex.org/W2398842109
#
#                                                                                         OpenAlex Title  \
# 518  Action of diphenesenic acid on the intestinal absorption of fats as determined in vivo in the rat
#
#     OpenAlex DOI                                  OpenAlex URL  \
# 518          NaN  https://www.ncbi.nlm.nih.gov/pubmed/13808286
#
#                        OpenAlex Venue  \
# 518  https://openalex.org/V2753293397
#
#                                                 OpenAlex Journal  \
# 518  Bollettino della Società italiana di biologia sperimentale
#
#           OpenAlex Publisher  OpenAlex First Page  OpenAlex Last Page
# 518  Boll Soc Ital Biol Sper               1783.0              1785.0

# %% [markdown]
# <!-- ## Experimenting methods to remove results for those four papers whose results are false -->
