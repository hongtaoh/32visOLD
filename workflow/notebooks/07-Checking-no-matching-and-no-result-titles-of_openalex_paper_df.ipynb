# %% [markdown]
# ## Aim
#
# In this notebook, I aim to see:
#
# - How many papers in `data/interim/title_query_empty_doi_query_404_dfs.txt` can be identified if I modify the queried title slightly
# - How many papers that are successfully identified (those in `data/processed/openalex_paper_df.csv`) do not have the same title and are not the same paper.
#
# ## Conclusion
#
# I conclude that the strategy I used in `get_openalex_dfs.py` works.

# %%
import requests
import pandas as pd
import csv
import re
pd.options.display.max_colwidth = 200
pd.set_option('display.max_rows', 500)
import numpy as np

# %%
def read_txt(INPUT):
    """read txt files and return a list
    """
    raw = open(INPUT, "r")
    reader = csv.reader(raw)
    allRows = [row for row in reader]
    data = [i[0] for i in allRows]
    return data

# %%
# where title query fails
no_matching = read_txt("../../data/interim/checking/title_query_404_dfs.txt")

# %%
# title query has empty results and doi query fails
no_result = read_txt("../../data/interim/checking/title_query_empty_doi_query_404_dfs.txt")

# %%
# doi query fails
failed_doi = read_txt("../../data/interim/checking/doi_query_404_dfs.txt")

# %%
# failed doi is the result of failed query for dois in `to_query_by_doi`. 
failed_doi
# Out:
# []

# %%
# create dicts to convert doi and title, and vice versa
vispd_plus = pd.read_csv("../../data/processed/vispubdata_plus.csv")
dois = vispd_plus.loc[:, "DOI"].tolist()
titles = vispd_plus.loc[:, "Title"].tolist()
doi_title_dict = dict(zip(dois, titles))
title_doi_dict = dict(zip(titles, dois))

# %%
# checking no matching.
no_matching_titles = [doi_title_dict[doi] for doi in no_matching]

# %%
no_matching_titles_transformed = [re.sub(r'\:|\?|\,|\#|\&', '', title) for title in no_matching_titles]

# %%
# empty, which means that every paper can be mathced. 
no_matching_titles
# Out:
# []

# %%
no_matching_titles_transformed
# Out:
# []

# %%
## checking no result titles
## By `no_result`, I mean that for these papers, title queries were successful
## However, the query does not show any result. For example:
## https://api.openalex.org/works?filter=title.search:Generation of Transfer Functions with Stochastic Search Technique
no_result_titles = [doi_title_dict[doi] for doi in no_result]
no_result_titles
no_result_titles_transformed = [re.sub(r'\:|\?|\,|\#|\&', '', title) for title in no_result_titles]
no_result_dois = [title_doi_dict[title] for title in no_result_titles]

# %%
no_result_titles_transformed
# Out:
# []

# %%
# build a df to show no result doi and title side by side, this is clearer
no_result_df = pd.DataFrame(columns = ['DOI', 'Title'])

# %%
no_result_df['DOI'] = no_result_dois
no_result_df['Title'] = no_result_titles

# %%
no_result_df
# Out:
# Empty DataFrame
# Columns: [DOI, Title]
# Index: []

# %% [markdown]
# ## Checking `openalex_paper_df.csv`

# %%
df = pd.read_csv("../../data/processed/openalex_paper_df.csv")
# df.Title != df['OpenAlex Title']) &

# %%
df.DOI[1]
df['OpenAlex DOI'][1]
# Out:
# 'https://doi.org/10.5555/949607.949654'

# %% [markdown]
# ## Checking the results where title queries were successful

# %%
# checking how many papers do not have openalex id; that is, how many failed. 
# i want to see whether the number match the total of no_result and no_match

df[df['OpenAlex ID'].isnull()].shape[0]

# Yes, it is correct
# Out:
# 0

# %%
# first, filter out those without openalex id
no_nan_df = df.dropna(subset=['OpenAlex ID'])
# create a new column based on DOI; the purpose is to compare it with OpenAlex DOI
no_nan_df = no_nan_df.assign(DOI_URL = [re.sub(r'^', 'https://doi.org/', doi) for doi in no_nan_df.DOI])
# then, show rows where both title and doi do not match
no_nan_df[(no_nan_df.Title.str.lower() != no_nan_df['OpenAlex Title'].str.lower()) & (
    no_nan_df['OpenAlex DOI'].str.lower() != no_nan_df['DOI_URL'].str.lower()
)]
# shape: (36, 23)
# Out:
#       Year                          DOI  \
# 93    1996   10.1109/VISUAL.1996.568113
# 147   1999   10.1109/VISUAL.1999.809896
# 158   1991   10.1109/VISUAL.1991.175771
# 175   1998   10.1109/VISUAL.1998.745302
# 261   1993   10.1109/VISUAL.1993.398859
# 262   2000   10.1109/VISUAL.2000.885685
# 350   1991   10.1109/VISUAL.1991.175795
# 389   1991   10.1109/VISUAL.1991.175789
# 414   2000   10.1109/VISUAL.2000.885739
# 523   1999   10.1109/VISUAL.1999.809871
# 573   1991   10.1109/VISUAL.1991.175777
# 704   1997   10.1109/VISUAL.1997.663909
# 807   2000   10.1109/VISUAL.2000.885697
# 968   1997   10.1109/VISUAL.1997.663910
# 1238  1996   10.1109/VISUAL.1996.568128
# 1339  1997   10.1109/VISUAL.1997.663923
# 1387  2011    10.1109/VAST.2011.6102441
# 1407  2000   10.1109/VISUAL.2000.885732
# 1435  2001   10.1109/VISUAL.2001.964522
# 1948  2005  10.1109/VISUAL.2005.1532847
# 2209  2000   10.1109/VISUAL.2000.885738
# 2330  1993   10.1109/VISUAL.1993.398865
# 2392  1993   10.1109/VISUAL.1993.398867
# 2718  1991   10.1109/VISUAL.1991.175816
# 2866  1993   10.1109/VISUAL.1993.398861
# 2867  1993   10.1109/VISUAL.1993.398872
# 2869  1993   10.1109/VISUAL.1993.398882
# 2873  1994   10.1109/VISUAL.1994.346292
# 2875  1994   10.1109/VISUAL.1994.346295
# 2876  1994   10.1109/VISUAL.1994.346297
# 2879  1994   10.1109/VISUAL.1994.346301
# 2896  2001   10.1109/VISUAL.2001.964546
# 2909  2020    10.1109/TVCG.2020.3028948
# 2983  2020    10.1109/TVCG.2020.3030363
# 3049  2020    10.1109/TVCG.2020.3030364
# 3120  2021    10.1109/tvcg.2021.3114782
#
#                                                                                                                                    Title  \
# 93                                                                     Generation of Transfer Functions with Stochastic Search Technique
# 147                                                               The "Parallel Vectors" operator-a vector field visualization primitive
# 158                                       The virtual windtunnel: An environment for the exploration of three-dimensional unsteady flows
# 175                                                                         TOPIC ISLANDS TM - a wavelet-based text visualization system
# 261                                                                     HyperSlice - Visualization of Scalar Functions of Many Variables
# 262                                         Automatic alignment of high-resolution multi-projector displays using an uncalibrated camera
# 350                                Color icons: merging color and texture perception for integrated visualization of multiple parameters
# 389                                                                    The stream polygon: A technique for 3D vector field visualization
# 414           WEAVE: a system for visually linking 3-D and statistical visualizations applied to cardiac simulation and measurement data
# 523                                                                             Image graphs-a novel approach to visual data exploration
# 573                                                                               Fast rotation of volume data on parallel architectures
# 704                                                                             Controlled simplification of genus for polygonal models
# 807                                                                                      Two-level volume rendering - fusing MIP and DVR
# 968                                                                     Vortex identification-applications in aerodynamics: a case study
# 1238  Virtual Workbench-a non-immersive virtual environment for visualizing and interacting with 3D objects for scientific visualization
# 1339                                                        Pearls found on the way to the ideal interface for scanned probe microscopes
# 1387                           Orion: A system for modeling, transformation and visualization of multidimensional heterogeneous networks
# 1407                                                                         Mastering interactive virtual bronchioscopy on a low-end PC
# 1435                                                                       RTVR-a flexible Java library for interactive volume rendering
# 1948                                                                              Profile Flags: a novel metaphor for probing of T₂ maps
# 2209                                  Vector fields simplification-a case study of visualizing climate modeling and simulation data sets
# 2330  DIVIDE: Distributed visual display of the execution of asynchronous, distributed algorithms on loosely-coupled parallel processors
# 2392                                                        Orientation maps: Techniques for visualizing rotations (A  Consumer's Guide)
# 2718                                                                                            How shall we connect our software tools?
# 2866                                                                    Developing modular application builders to exploit MIMD parallel
# 2867                                                         Towards a texture naming system: Identifying relevant dimensions of texture
# 2869                                                                   Fast analytical computation of Richard's smooth molecular surface
# 2873                                                                              Visualization of an electric power transmission system
# 2875                                                                         Observing a volume rendered fetus within a pregnant patient
# 2876                                                                            Visualization of mesoscale flow features in ocean basins
# 2879                                                                                             Tokamak plasma turbulence visualization
# 2896                                                          Chromatin decondensation: case study of tracking features in confocal data
# 2909                                       A Generic Framework and Library for Exploration of Small Multiples through Interactive Piling
# 2983                                                 Improving the Usability of Virtual Reality Neuron Tracing with Topological Elements
# 3049                                              Supporting the Problem-Solving Loop: Designing Highly Interactive Optimisation Systems
# 3120                           An Automated Approach to Reasoning About Task-Oriented Visualization Insights in Responsive Visualization
#
#       OpenAlex Year OpenAlex Publication Date  OpenAlex ID  \
# 93             1996                1996-10-27  W1964910730
# 147            1999                1999-10-24  W2095105262
# 158            1991                1991-10-22  W2114975239
# 175            1998                1998-10-18  W2136452290
# 261            1993                1993-10-25  W2103111128
# 262            2000                2000-10-01  W2170549385
# 350            1991                1991-10-22  W1991928089
# 389            1991                1991-10-22  W2077014479
# 414            2000                2000-10-01  W2089875636
# 523            1999                1999-10-24  W2018246367
# 573            1991                1991-10-22  W2128435165
# 704            1997                1997-10-01  W2155412154
# 807            2000                2000-10-01  W1990028735
# 968            1997                1997-10-01  W2129302988
# 1238           1996                1996-10-27  W2131777532
# 1339           1997                1997-10-01  W2141871926
# 1387           2014                2014-04-01  W2068966762
# 1407           2000                2000-10-01  W1993673415
# 1435           2001                2001-10-21  W2150898819
# 1948           2005                2005-11-21  W2143277319
# 2209           2000                2000-10-01  W2020079884
# 2330           1994                1994-11-01  W2052097245
# 2392           1993                1993-10-25  W2140793785
# 2718           1991                1991-10-22  W2115973673
# 2866           1993                1993-10-25  W2133430557
# 2867           1996                1996-06-01  W2095363539
# 2869           1993                1993-10-25  W2099803286
# 2873           1994                1994-10-17  W2147491968
# 2875           1994                1994-10-17  W2136046800
# 2876           1994                1994-10-17  W2099243101
# 2879           1994                1994-10-17  W2088778374
# 2896           2001                2001-10-21  W2008347373
# 2909           2020                2020-05-01  W3023951087
# 2983           2020                2020-09-03  W3083399682
# 3049           2020                2020-09-07  W3083286135
# 3120           2021                2021-07-16  W3186894540
#
#                                                                                                                             OpenAlex Title  \
# 93                                                                      Generation of transfer functions with stochastic search techniques
# 147                                                                The “parallel vectors” operator: a vector field visualization primitive
# 158                                          The virtual windtunnel-an environment for the exploration of three-dimensional unsteady flows
# 175                                                                        TOPIC ISLANDS/sup TM/-a wavelet-based text visualization system
# 261                                                                        HyperSlice: visualization of scalar functions of many variables
# 262                                           Automatic alignment of high-resolution multi-projector display using an un-calibrated camera
# 350                                   Color icons-merging color and texture perception for integrated visualization of multiple parameters
# 389                                                                       The stream polygon-a technique for 3D vector field visualization
# 414            WEAVE: a system for visually linking 3-D and statistical visualizations, applied to cardiac simulation and measurement data
# 523                                                                               Image graphs—a novel approach to visual data exploration
# 573                                                                            Fast rotation of volume data on data parallel architectures
# 704                                                                                Controlled simplification of genus for polygonal models
# 807                                                                                        Two-level volume rendering — fusing MIP and DVR
# 968                                                                       Vortex identification—applications in aerodynamics: a case study
# 1238  Virtual workbench - a non-immersive virtual environment for visualizing and interacting with 3D objects for scientific visualization
# 1339                                                          Pearls found on the way to the ideal interface for scanned-probe microscopes
# 1387                            Orion: A system for modeling, transformation and visualization of multidimensional heterogeneous networks:
# 1407                                                                           Mastering interactive virtual Bronchioscopy on a Low—end PC
# 1435                                                                        RTVR: a flexible java library for interactive volume rendering
# 1948                                                                          Profile Flags: a novel metaphor for probing of T/sub 2/ maps
# 2209                                  Vector fields simplification — a case study of visualizing climate modeling and simulation data sets
# 2330    DIVIDE: Distributed visual display of the execution of asynchronous, distributed algorithms on loosely coupled parallel processors
# 2392                                                           Orientation maps: techniques for visualizing rotations (a consumer's guide)
# 2718                                                                                               How shall we connect our software tools
# 2866                                                            Developing modular application builders to exploit MIMD parallel resources
# 2867                                                          Towards a texture naming system: identifying relevant dimensions of texture.
# 2869                                                                    Fast analytical computation of Richards's smooth molecular surface
# 2873                                                                    Case study: visualization of an electric power transmission system
# 2875                                                               Case study: observing a volume rendered fetus within a pregnant patient
# 2876                                                                  Case study: visualization of mesoscale flow features in ocean basins
# 2879                                                                                   Case study: tokamak plasma turbulence visualization
# 2896                                                          Chromatin decondensation: a case study of tracking features in confocal data
# 2909                                        A Generic Framework and Library for Exploration of Small Multiples through Interactive Piling.
# 2983                                                  Improving the Usability of Virtual Reality Neuron Tracing with Topological Elements.
# 3049                                               Supporting the Problem-Solving Loop: Designing Highly Interactive Optimisation Systems.
# 3120                                           An Automated Approach to Reasoning About Task-Oriented Insights in Responsive Visualization
#
#                                       OpenAlex DOI  \
# 93           https://doi.org/10.5555/244979.245572
# 147          https://doi.org/10.5555/319351.319420
# 158          https://doi.org/10.5555/949607.949612
# 175          https://doi.org/10.5555/288216.288247
# 261          https://doi.org/10.5555/949845.949871
# 262          https://doi.org/10.5555/375213.375230
# 350          https://doi.org/10.5555/949607.949634
# 389          https://doi.org/10.5555/949607.949628
# 414          https://doi.org/10.5555/375213.375311
# 523          https://doi.org/10.5555/319351.319360
# 573          https://doi.org/10.5555/949607.949616
# 704          https://doi.org/10.5555/266989.267109
# 807          https://doi.org/10.5555/375213.375244
# 968          https://doi.org/10.5555/266989.267110
# 1238         https://doi.org/10.5555/244979.245631
# 1339         https://doi.org/10.5555/266989.267123
# 1387      https://doi.org/10.1177/1473871612462152
# 1407         https://doi.org/10.5555/375213.375298
# 1435         https://doi.org/10.5555/601671.601714
# 1948           https://doi.org/10.1109/vis.2005.81
# 2209         https://doi.org/10.5555/375213.375309
# 2330  https://doi.org/10.1016/0097-8493(94)90012-4
# 2392         https://doi.org/10.5555/949845.949881
# 2718         https://doi.org/10.5555/949607.949655
# 2866         https://doi.org/10.5555/949845.949873
# 2867  https://doi.org/10.1016/0042-6989(95)00202-2
# 2869         https://doi.org/10.5555/949845.949900
# 2873         https://doi.org/10.5555/951087.951160
# 2875         https://doi.org/10.5555/951087.951156
# 2876         https://doi.org/10.5555/951087.951153
# 2879         https://doi.org/10.5555/951087.951148
# 2896         https://doi.org/10.5555/601671.601744
# 2909                                           NaN
# 2983                                           NaN
# 3049                                           NaN
# 3120                                           NaN
#
#                                                                                     OpenAlex URL  \
# 93                 http://dblp.uni-trier.de/db/conf/visualization/visualization1996.html#HeHKP96
# 147            https://dblp.uni-trier.de/db/conf/visualization/visualization1999.html#PeikertR99
# 158                                                  http://ieeexplore.ieee.org/document/175771/
# 175                                                   https://doi.org/10.1109/VISUAL.1998.745302
# 261                                                   https://doi.org/10.1109/VISUAL.1993.398859
# 262                                 https://www.ics.uci.edu/~majumder/vispercep/vis2000_chen.pdf
# 350           https://dblp.uni-trier.de/db/conf/visualization/visualization1991.html#Levkowitz91
# 389                                                 https://dl.acm.org/doi/10.5555/949607.949628
# 414           https://dblp.uni-trier.de/db/conf/visualization/visualization2000.html#GreshRWSY00
# 523                   http://dblp.uni-trier.de/db/conf/visualization/visualization1999.html#Ma99
# 573                                                  http://ieeexplore.ieee.org/document/175777/
# 704                                 https://www.cs.umd.edu/projects/gvil/papers/elsana_vis97.pdf
# 807           https://dblp.uni-trier.de/db/conf/visualization/visualization2000.html#HauserMBG00
# 968          https://dblp.uni-trier.de/db/conf/visualization/visualization1997.html#KenwrightH97
# 1238  http://dblp.uni-trier.de/db/conf/visualization/visualization1996.html#ObeysekareWDRRGRLS96
# 1339                   https://www.cs.unc.edu/~taylorr/cyberinfrastructure/1997vis97_reprint.pdf
# 1387                                                    https://doi.org/10.1177/1473871612462152
# 1407                         https://www.cg.tuwien.ac.at/research/vis/vismed/EndoWeb/endoweb.pdf
# 1435                                                 http://ieeexplore.ieee.org/document/964522/
# 1948                                                         https://doi.org/10.1109/vis.2005.81
# 2209                     http://yadda.icm.edu.pl/yadda/element/bwmeta1.element.ieee-000000885738
# 2330                                                https://doi.org/10.1016/0097-8493(94)90012-4
# 2392                                                https://dl.acm.org/doi/10.5555/949845.949881
# 2718             https://dblp.uni-trier.de/db/conf/visualization/visualization1991.html#Grosse91
# 2866                       https://surface.syr.edu/cgi/viewcontent.cgi?article=1074&context=npac
# 2867                                                https://doi.org/10.1016/0042-6989(95)00202-2
# 2869          https://dblp.uni-trier.de/db/conf/visualization/visualization1993.html#VarshneyB93
# 2873                                                  https://doi.org/10.1109/VISUAL.1994.346292
# 2875                                               https://www.cs.unc.edu/techreports/94-034.pdf
# 2876         https://dblp.uni-trier.de/db/conf/visualization/visualization1994.html#JohannsenM94
# 2879            https://dblp.uni-trier.de/db/conf/visualization/visualization1994.html#ParkerS94
# 2896                                                 http://ieeexplore.ieee.org/document/964546/
# 2909                                                        https://arxiv.org/pdf/2005.00595.pdf
# 2983                                                            https://arxiv.org/abs/2009.01891
# 3049                                                        https://arxiv.org/pdf/2009.03163.pdf
# 3120                                                        https://arxiv.org/pdf/2107.08141.pdf
#
#                      OpenAlex Venue ID  ... OpenAlex First Page  \
# 93                                 NaN  ...               227.0
# 147                                NaN  ...               263.0
# 158                                NaN  ...                17.0
# 175                                NaN  ...               189.0
# 261                                NaN  ...               119.0
# 262                                NaN  ...               125.0
# 350                                NaN  ...               164.0
# 389                                NaN  ...               126.0
# 414                                NaN  ...               489.0
# 523                                NaN  ...                81.0
# 573                                NaN  ...                50.0
# 704                                NaN  ...               403.0
# 807                                NaN  ...               211.0
# 968                                NaN  ...               413.0
# 1238                               NaN  ...               345.0
# 1339                               NaN  ...               467.0
# 1387    https://openalex.org/V55152591  ...               111.0
# 1407                               NaN  ...               461.0
# 1435                               NaN  ...               279.0
# 1948                               NaN  ...               599.0
# 2209                               NaN  ...               485.0
# 2330    https://openalex.org/V94821547  ...               849.0
# 2392                               NaN  ...               183.0
# 2718                               NaN  ...               292.0
# 2866                               NaN  ...               134.0
# 2867    https://openalex.org/V68719679  ...              1649.0
# 2869                               NaN  ...               300.0
# 2873                               NaN  ...               379.0
# 2875                               NaN  ...               364.0
# 2876                               NaN  ...               355.0
# 2879                               NaN  ...               337.0
# 2896                               NaN  ...               441.0
# 2909  https://openalex.org/V2595899084  ...                 NaN
# 2983  https://openalex.org/V2596830251  ...                 NaN
# 3049  https://openalex.org/V2595899084  ...                 NaN
# 3120  https://openalex.org/V2595899084  ...                 NaN
#
#      OpenAlex Last Page Number of Pages  Number of References  \
# 93                234.0             8.0                    16
# 147               270.0             8.0                    26
# 158                24.0             8.0                     7
# 175               196.0             8.0                    24
# 261               125.0             7.0                     7
# 262               130.0             6.0                    15
# 350               170.0             7.0                     9
# 389               132.0             7.0                     6
# 414               492.0             4.0                    17
# 523                88.0             8.0                    13
# 573                57.0             8.0                    23
# 704               410.0             8.0                    39
# 807               218.0             8.0                    21
# 968               416.0             4.0                    16
# 1238              349.0             5.0                     8
# 1339              470.0             4.0                     6
# 1387              133.0            23.0                    30
# 1407              464.0             4.0                    18
# 1435              286.0             8.0                    29
# 1948              606.0             8.0                    19
# 2209              488.0             4.0                     8
# 2330              859.0            11.0                    29
# 2392              188.0             6.0                     8
# 2718              296.0             5.0                     2
# 2866              141.0             8.0                     0
# 2867             1669.0            21.0                    33
# 2869              307.0             8.0                    17
# 2873              381.0             3.0                     4
# 2875              368.0             5.0                    14
# 2876              358.0             4.0                     9
# 2879              340.0             4.0                     0
# 2896              444.0             4.0                     9
# 2909                NaN             NaN                    43
# 2983                NaN             NaN                    59
# 3049                NaN             NaN                    45
# 3120                NaN             NaN                    69
#
#       Number of Authors  Number of Concepts  Number of Citations  \
# 93                    4                   5                  186
# 147                   2                   7                  147
# 158                   2                   4                  143
# 175                   4                  10                   77
# 261                   2                   5                  108
# 262                   5                  11                   90
# 350                   1                  16                   85
# 389                   3                  12                   77
# 414                   5                   6                   75
# 523                   1                   8                   73
# 573                   2                   5                   60
# 704                   2                   6                   52
# 807                   4                  10                   39
# 968                   2                  10                   37
# 1238                  9                  17                   27
# 1339                 12                   7                   23
# 1387                  2                   4                   36
# 1407                  6                   6                   20
# 1435                  2                  15                   22
# 1948                  7                   4                   11
# 2209                  6                   6                    9
# 2330                  2                   9                    3
# 2392                  4                   8                   22
# 2718                  1                   4                    0
# 2866                  3                   8                    6
# 2867                  2                   8                  154
# 2869                  2                   5                   25
# 2873                  2                  12                    7
# 2875                  8                  10                   80
# 2876                  2                   8                    7
# 2879                  2                   8                    4
# 2896                  2                   4                    8
# 2909                  6                   2                    0
# 2983                  8                   6                    0
# 3049                  5                   5                    1
# 3120                  5                   6                    0
#
#                                              Citation API URL  \
# 93    https://api.openalex.org/works?filter=cites:W1964910730
# 147   https://api.openalex.org/works?filter=cites:W2095105262
# 158   https://api.openalex.org/works?filter=cites:W2114975239
# 175   https://api.openalex.org/works?filter=cites:W2136452290
# 261   https://api.openalex.org/works?filter=cites:W2103111128
# 262   https://api.openalex.org/works?filter=cites:W2170549385
# 350   https://api.openalex.org/works?filter=cites:W1991928089
# 389   https://api.openalex.org/works?filter=cites:W2077014479
# 414   https://api.openalex.org/works?filter=cites:W2089875636
# 523   https://api.openalex.org/works?filter=cites:W2018246367
# 573   https://api.openalex.org/works?filter=cites:W2128435165
# 704   https://api.openalex.org/works?filter=cites:W2155412154
# 807   https://api.openalex.org/works?filter=cites:W1990028735
# 968   https://api.openalex.org/works?filter=cites:W2129302988
# 1238  https://api.openalex.org/works?filter=cites:W2131777532
# 1339  https://api.openalex.org/works?filter=cites:W2141871926
# 1387  https://api.openalex.org/works?filter=cites:W2068966762
# 1407  https://api.openalex.org/works?filter=cites:W1993673415
# 1435  https://api.openalex.org/works?filter=cites:W2150898819
# 1948  https://api.openalex.org/works?filter=cites:W2143277319
# 2209  https://api.openalex.org/works?filter=cites:W2020079884
# 2330  https://api.openalex.org/works?filter=cites:W2052097245
# 2392  https://api.openalex.org/works?filter=cites:W2140793785
# 2718  https://api.openalex.org/works?filter=cites:W2115973673
# 2866  https://api.openalex.org/works?filter=cites:W2133430557
# 2867  https://api.openalex.org/works?filter=cites:W2095363539
# 2869  https://api.openalex.org/works?filter=cites:W2099803286
# 2873  https://api.openalex.org/works?filter=cites:W2147491968
# 2875  https://api.openalex.org/works?filter=cites:W2136046800
# 2876  https://api.openalex.org/works?filter=cites:W2099243101
# 2879  https://api.openalex.org/works?filter=cites:W2088778374
# 2896  https://api.openalex.org/works?filter=cites:W2008347373
# 2909  https://api.openalex.org/works?filter=cites:W3023951087
# 2983  https://api.openalex.org/works?filter=cites:W3083399682
# 3049  https://api.openalex.org/works?filter=cites:W3083286135
# 3120  https://api.openalex.org/works?filter=cites:W3186894540
#
#       Number of Citation API URLs                                      DOI_URL
# 93                              1   https://doi.org/10.1109/VISUAL.1996.568113
# 147                             1   https://doi.org/10.1109/VISUAL.1999.809896
# 158                             1   https://doi.org/10.1109/VISUAL.1991.175771
# 175                             1   https://doi.org/10.1109/VISUAL.1998.745302
# 261                             1   https://doi.org/10.1109/VISUAL.1993.398859
# 262                             1   https://doi.org/10.1109/VISUAL.2000.885685
# 350                             1   https://doi.org/10.1109/VISUAL.1991.175795
# 389                             1   https://doi.org/10.1109/VISUAL.1991.175789
# 414                             1   https://doi.org/10.1109/VISUAL.2000.885739
# 523                             1   https://doi.org/10.1109/VISUAL.1999.809871
# 573                             1   https://doi.org/10.1109/VISUAL.1991.175777
# 704                             1   https://doi.org/10.1109/VISUAL.1997.663909
# 807                             1   https://doi.org/10.1109/VISUAL.2000.885697
# 968                             1   https://doi.org/10.1109/VISUAL.1997.663910
# 1238                            1   https://doi.org/10.1109/VISUAL.1996.568128
# 1339                            1   https://doi.org/10.1109/VISUAL.1997.663923
# 1387                            1    https://doi.org/10.1109/VAST.2011.6102441
# 1407                            1   https://doi.org/10.1109/VISUAL.2000.885732
# 1435                            1   https://doi.org/10.1109/VISUAL.2001.964522
# 1948                            1  https://doi.org/10.1109/VISUAL.2005.1532847
# 2209                            1   https://doi.org/10.1109/VISUAL.2000.885738
# 2330                            1   https://doi.org/10.1109/VISUAL.1993.398865
# 2392                            1   https://doi.org/10.1109/VISUAL.1993.398867
# 2718                            1   https://doi.org/10.1109/VISUAL.1991.175816
# 2866                            1   https://doi.org/10.1109/VISUAL.1993.398861
# 2867                            1   https://doi.org/10.1109/VISUAL.1993.398872
# 2869                            1   https://doi.org/10.1109/VISUAL.1993.398882
# 2873                            1   https://doi.org/10.1109/VISUAL.1994.346292
# 2875                            1   https://doi.org/10.1109/VISUAL.1994.346295
# 2876                            1   https://doi.org/10.1109/VISUAL.1994.346297
# 2879                            1   https://doi.org/10.1109/VISUAL.1994.346301
# 2896                            1   https://doi.org/10.1109/VISUAL.2001.964546
# 2909                            1    https://doi.org/10.1109/TVCG.2020.3028948
# 2983                            1    https://doi.org/10.1109/TVCG.2020.3030363
# 3049                            1    https://doi.org/10.1109/TVCG.2020.3030364
# 3120                            1    https://doi.org/10.1109/tvcg.2021.3114782
#
# [36 rows x 23 columns]

# %%
# all papers above are matched correctly
# EVERYTHING CORRECT
wrong_match_dois = [
]

# %%
# there are a totle of 3,233 papers, correct
df.shape
# Out:
# (3233, 22)
